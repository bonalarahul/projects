# %% [markdown]
# Uploading libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# Reading Data

# %%
mangr = pd.read_csv('C:/Users/lonovo/Downloads/train_LZdllcl.csv')
mangr.head()
mangr_test=pd.read_csv('C:/Users/lonovo/Downloads/test_2umaH9m.csv')

# %% [markdown]
# Looking through columns and their data types

# %% [markdown]
# mangr.columns

# %%
mangr.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# KPIs_met >80%             int64
# awards_won?               int64
# avg_training_score        int64
# is_promoted               int64
# dtype: object

# %% [markdown]
# Shape of data frame

# %%
mangr.shape
# Out:
# (54808, 14)

# %% [markdown]
# Univariate analysis

# %%
mangr['is_promoted'].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %% [markdown]
# Normalize can be set to True to print proportions instead of number

# %%
mangr['is_promoted'].value_counts(normalize = True)
# Out:
# 0    0.91483
# 1    0.08517
# Name: is_promoted, dtype: float64

# %%
mangr['is_promoted'].value_counts().plot.bar()

# %% [markdown]
#  Visualizing categorical features

# %%
plt.figure(1)
plt.subplot(221)
mangr['department'].value_counts(normalize = True).plot.bar(figsize = (15,10),title = "department")

plt.subplot(222)
mangr['recruitment_channel'].value_counts(normalize = True).plot.bar(title = 'recruitment_channel')

plt.subplot(223)
mangr['education'].value_counts(normalize = True).plot.bar(title = 'Education')

plt.subplot(224)
mangr['gender'].value_counts(normalize = True).plot.bar(title = 'Gender')

# %%
mangr['region'].value_counts(normalize = True).plot.bar(figsize = (15,6))

# %%
mangr['no_of_trainings'].value_counts(normalize = True).sort_values().plot.bar(figsize = (15,6))

# %%
mangr['length_of_service'].value_counts(normalize = True).plot.bar(figsize = (15,6))

# %%
plt.figure(1)
Visualizing numerical features
plt.subplot(131)
mangr['previous_year_rating'].value_counts(normalize = True).plot.bar(figsize = (10,4))
plt.xlabel("prev_year_rating")

plt.subplot(132)
mangr['KPIs_met >80%'].value_counts(normalize = True).plot.bar()
plt.xlabel("KPI")

plt.subplot(133)
mangr['awards_won?'].value_counts(normalize = True).plot.bar()
plt.xlabel("awards_won")
# Out:
# Text(0.5, 0, 'awards_won')

# %% [markdown]
# Visualizing numerical features

# %%
plt.figure(1)

plt.subplot(121)
sns.distplot(mangr['avg_training_score'])

plt.subplot(122)
mangr['avg_training_score'].plot.box(figsize = (12,6))

# %% [markdown]
# Bi-variate Analysis

# %%
print(pd.crosstab(mangr['department'],mangr['is_promoted']))
# Out:
# is_promoted            0     1
# department
# Analytics           4840   512
# Finance             2330   206
# HR                  2282   136
# Legal                986    53
# Operations         10325  1023
# Procurement         6450   688
# R&D                  930    69
# Sales & Marketing  15627  1213
# Technology          6370   768

# %%
dep = pd.crosstab(mangr['department'],mangr['is_promoted'])
dep.plot(kind = 'bar', stacked = True, figsize = (5,5))

# %%
print(pd.crosstab(mangr['region'],mangr['is_promoted']))
# Out:
# is_promoted      0    1
# region
# region_1       552   58
# region_10      597   51
# region_11     1241   74
# region_12      467   33
# region_13     2418  230
# region_14      765   62
# region_15     2586  222
# region_16     1363  102
# region_17      687  109
# region_18       30    1
# region_19      821   53
# region_2     11354  989
# region_20      801   49
# region_21      393   18
# region_22     5694  734
# region_23     1038  137
# region_24      490   18
# region_25      716  103
# region_26     2117  143
# region_27     1528  131
# region_28     1164  154
# region_29      951   43
# region_3       309   37
# region_30      598   59
# region_31     1825  110
# region_32      905   40
# region_33      259   10
# region_34      284    8
# region_4      1457  246
# region_5       731   35
# region_6       658   32
# region_7      4327  516
# region_8       602   53
# region_9       412    8

# %%
reg = pd.crosstab(mangr['region'],mangr['is_promoted'])
reg.plot(kind = 'bar' , stacked = True , figsize = (15,6))

# %%
print(pd.crosstab(mangr['education'],mangr['is_promoted']))
# Out:
# is_promoted           0     1
# education
# Bachelor's        33661  3008
# Below Secondary     738    67
# Master's & above  13454  1471

# %%
edu = pd.crosstab(mangr['education'],mangr['is_promoted'])
edu.plot(kind = 'bar' , stacked  = True , figsize = (8,4))

# %%
print(pd.crosstab(mangr['gender'],mangr['is_promoted']))
# Out:
# is_promoted      0     1
# gender
# f            14845  1467
# m            35295  3201

# %%
gen = pd.crosstab(mangr['gender'],mangr['is_promoted'])
gen.plot(kind = 'bar' , stacked = True , figsize = (4,4))

# %%
print(pd.crosstab(mangr['recruitment_channel'],mangr['is_promoted']))
# Out:
# is_promoted              0     1
# recruitment_channel
# other                27890  2556
# referred              1004   138
# sourcing             21246  1974

# %%
recr = pd.crosstab(mangr['recruitment_channel'],mangr['is_promoted'])
recr.plot(kind = 'bar' , stacked = True , figsize = (4,4))

# %%
print(pd.crosstab(mangr['no_of_trainings'],mangr['is_promoted']))
# Out:
# is_promoted          0     1
# no_of_trainings
# 1                40468  3910
# 2                 7382   605
# 3                 1654   122
# 4                  442    26
# 5                  125     3
# 6                   42     2
# 7                   12     0
# 8                    5     0
# 9                    5     0
# 10                   5     0

# %%
no_training = pd.crosstab(mangr['no_of_trainings'],mangr['is_promoted'])
no_training.plot(kind = 'bar' , stacked = True , figsize = (9,4))

# %%
print(pd.crosstab(mangr['previous_year_rating'],mangr['is_promoted']))
# Out:
# is_promoted               0     1
# previous_year_rating
# 1.0                    6135    88
# 2.0                    4044   181
# 3.0                   17263  1355
# 4.0                    9093   784
# 5.0                    9820  1921

# %%
prevrat = pd.crosstab(mangr['previous_year_rating'],mangr['is_promoted'])
prevrat.plot(kind = 'bar' , stacked = True , figsize = (4,4))

# %%
print(pd.crosstab(mangr['length_of_service'],mangr['is_promoted']))
# Out:
# is_promoted           0    1
# length_of_service
# 1                  4170  377
# 2                  6089  595
# 3                  6424  609
# 4                  6238  598
# 5                  5357  475
# 6                  4333  401
# 7                  5087  464
# 8                  2614  269
# 9                  2400  229
# 10                 1989  204
# 11                  820   96
# 12                  731   63
# 13                  633   54
# 14                  520   29
# 15                  550   43
# 16                  507   41
# 17                  406   26
# 18                  367   25
# 19                  297   32
# 20                  118   10
# 21                   74    4
# 22                   55    6
# 23                   58    7
# 24                   70    0
# 25                   49    2
# 26                   41    0
# 27                   35    1
# 28                   28    2
# 29                   27    3
# 30                   12    0
# ...

# %%
service = pd.crosstab(mangr['length_of_service'],mangr['is_promoted'])
service.plot(kind = 'bar' , stacked = True , figsize = (15,4))

# %%
print(pd.crosstab(mangr['KPIs_met >80%'],mangr['is_promoted']))
# Out:
# is_promoted        0     1
# KPIs_met >80%
# 0              34111  1406
# 1              16029  3262

# %%
kpi = pd.crosstab(mangr['KPIs_met >80%'],mangr['is_promoted'])
kpi.plot(kind = 'bar' , stacked = True , figsize = (4,4))

# %%
print(pd.crosstab(mangr['awards_won?'],mangr['is_promoted']))
# Out:
# is_promoted      0     1
# awards_won?
# 0            49429  4109
# 1              711   559

# %%
awards = pd.crosstab(mangr['awards_won?'],mangr['is_promoted'])
awards.plot(kind = 'bar' , stacked = True , figsize = (4,4))

# %%
bins = [0,30,50,60]
group = ['young','middle','old']

mangr['age_bin'] = pd.cut(mangr['age'],bins,labels = group)

# %%
print(pd.crosstab(mangr['age_bin'],mangr['is_promoted']))
# Out:
# is_promoted      0     1
# age_bin
# young        16568  1550
# middle       30911  2927
# old           2661   191

# %%
age_bin = pd.crosstab(mangr['age_bin'],mangr['is_promoted'])
age_bin.plot(kind = 'bar' , stacked = True , figsize = (5,4))

# %%
bins = [0,50,60,70,100]
group = ['Low','Avg','High','Very High']
mangr['score_bin'] = pd.cut(mangr['avg_training_score'],bins,labels = group)

# %%
print(pd.crosstab(mangr['score_bin'],mangr['is_promoted']))
# Out:
# is_promoted      0     1
# score_bin
# Low          11529   474
# Avg          15141   879
# High          9047   926
# Very High    14423  2389

# %%
score_bin = pd.crosstab(mangr['score_bin'],mangr['is_promoted'])
score_bin.plot(kind = 'bar' , stacked = True , figsize = (6,4))

# %% [markdown]
# Drop the new variable of bins

# %%
mangr = mangr.drop(['score_bin','age_bin'],axis = 1)

# %%
mangr1 = mangr.drop(['employee_id','age'],axis = 1)

matrix = mangr1.corr()
matrix
# Out:
#                       no_of_trainings  previous_year_rating  \
# no_of_trainings              1.000000             -0.063126
# previous_year_rating        -0.063126              1.000000
# length_of_service           -0.057275              0.000253
# KPIs_met >80%               -0.045576              0.351578
# awards_won?                 -0.007628              0.027738
# avg_training_score           0.042517              0.075139
# is_promoted                 -0.024896              0.159320
#
#                       length_of_service  KPIs_met >80%  awards_won?  \
# no_of_trainings               -0.057275      -0.045576    -0.007628
# previous_year_rating           0.000253       0.351578     0.027738
# length_of_service              1.000000      -0.077693    -0.039927
# KPIs_met >80%                 -0.077693       1.000000     0.097000
# awards_won?                   -0.039927       0.097000     1.000000
# avg_training_score            -0.038122       0.078391     0.072138
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(mangr.drop(['employee_id','age'],axis = 1),alpha = 0.5,figsize = (14,10),diagonal = 'hist')

# %% [markdown]
# MIssing Value Analysis & imputation

# %%
mangr.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %% [markdown]
# Plotting the missing value information

# %%
miss = mangr.isnull().sum()
miss.plot(kind = 'barh' )

# %% [markdown]
# Getting the percentage of missing values -- train

# %%
x = round((mangr.isnull().sum()/len(mangr.index))*100,3)
x[x>0]
# Out:
# education               4.395
# previous_year_rating    7.524
# dtype: float64

# %% [markdown]
# Getting the percentage of missing values -- test

# %%
t = round((mangr_test.isnull().sum()/len(mangr_test.index))*100,3)
t[t>0]
# Out:
# education               4.402
# previous_year_rating    7.714
# dtype: float64

# %%
mangr.education.mode()
# Out:
# 0    Bachelor's
# dtype: object

# %% [markdown]
# replacing the missing values with the mode  -- train

# %%
mangr['education'].fillna(mangr['education'].mode()[0],inplace = True)

# %% [markdown]
# replacing the missing values with the mode  -- test

# %%
mangr_test['education'].fillna(mangr_test['education'].mode()[0],inplace = True)

# %%
print(pd.crosstab(mangr['previous_year_rating'],mangr['KPIs_met >80%']))
# Out:
# KPIs_met >80%             0     1
# previous_year_rating
# 1.0                    5424   799
# 2.0                    3456   769
# 3.0                   13810  4808
# 4.0                    5899  3978
# 5.0                    4246  7495

# %%
print(pd.crosstab(mangr_test['previous_year_rating'],mangr_test['KPIs_met >80%']))
# Out:
# KPIs_met >80%            0     1
# previous_year_rating
# 1.0                   2322   358
# 2.0                   1403   328
# 3.0                   5827  2094
# 4.0                   2516  1733
# 5.0                   1827  3270

# %%
print(pd.crosstab(mangr['previous_year_rating'],mangr['awards_won?']))
# Out:
# awards_won?               0    1
# previous_year_rating
# 1.0                    6114  109
# 2.0                    4152   73
# 3.0                   18211  407
# 4.0                    9651  226
# 5.0                   11382  359

# %%
mangr.previous_year_rating[(mangr.previous_year_rating.isnull()) & (mangr['KPIs_met >80%'] == 1)] = 5
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mangr.previous_year_rating[(mangr.previous_year_rating.isnull()) & (mangr['KPIs_met >80%'] == 0)] = 3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mangr_test.previous_year_rating[(mangr_test.previous_year_rating.isnull()) & (mangr_test['KPIs_met >80%'] == 1)] = 5
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mangr_test.previous_year_rating[(mangr_test.previous_year_rating.isnull()) & (mangr_test['KPIs_met >80%'] == 0)] = 3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mangr.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
mangr['avg_training_score_log'] = np.log(mangr['avg_training_score'])
mangr['avg_training_score_log'].hist()

# %%
mangr = pd.get_dummies(mangr)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(mangr.drop('is_promoted',axis=1), 
                                                    mangr['is_promoted'], test_size=0.30, 
                                                    random_state=101)

# %%
train_original.dtypes
# Out:
# employee_id                       int64
# no_of_trainings                   int64
# age                               int64
# previous_year_rating            float64
# length_of_service                 int64
# KPIs_met >80%                     int64
# awards_won?                       int64
# avg_training_score                int64
# is_promoted                       int64
# department_Analytics              uint8
# department_Finance                uint8
# department_HR                     uint8
# department_Legal                  uint8
# department_Operations             uint8
# department_Procurement            uint8
# department_R&D                    uint8
# department_Sales & Marketing      uint8
# department_Technology             uint8
# region_region_1                   uint8
# region_region_10                  uint8
# region_region_11                  uint8
# region_region_12                  uint8
# region_region_13                  uint8
# ...

# %% [markdown]
# Applying logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     15061
#            1       0.00      0.00      0.00      1382
#
#     accuracy                           0.92     16443
#    macro avg       0.46      0.50      0.48     16443
# weighted avg       0.84      0.92      0.88     16443
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Applying Decision tree classification

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     15061
#            1       0.42      0.47      0.44      1382
#
#     accuracy                           0.90     16443
#    macro avg       0.69      0.71      0.70     16443
# weighted avg       0.91      0.90      0.90     16443

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[14174   887]
#  [  733   649]]

# %% [markdown]
# Applying Random Forest classification

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=700)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=700,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[15043    18]
#  [  958   424]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     15061
#            1       0.96      0.31      0.46      1382
#
#     accuracy                           0.94     16443
#    macro avg       0.95      0.65      0.72     16443
# weighted avg       0.94      0.94      0.93     16443
